# %% [markdown]
# # Subset barcode runs
# This Python Jupyter notebook is creates a copy of the barcode runs file that contains just specific samples.
#
# First, import Python modules:

# %%
import os

import pandas as pd

import yaml

# %% [markdown]
# Read in the "master" barcode runs CSV file and the runs used to compute the escape scores for each sample:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

barcode_runs_file = os.path.join('../', config['barcode_runs'])
print(f"Reading barcode runs from {barcode_runs_file}")
barcode_runs = pd.read_csv(barcode_runs_file)

escape_score_samples_file = os.path.join('../', config['escape_score_samples'])
print(f"Reading escape score samples from {escape_score_samples_file}")
escape_score_samples = pd.read_csv(escape_score_samples_file)
# Out:
# Reading barcode runs from ../data/barcode_runs.csv
# Reading escape score samples from ../results/escape_scores/samples.csv

# %% [markdown]
# Now read in the samples to subset:

# %%
samples_to_subset_df = pd.read_csv('samples_to_subset.csv')
print('Here are the samples we will subset to:')
display(samples_to_subset_df)

samples_to_subset = samples_to_subset_df['sample'].tolist()
assert len(samples_to_subset) == len(set(samples_to_subset)), 'duplicate samples to subset'
# Out:
# Here are the samples we will subset to:
#           sample
# 0     CR3022_400
# 1  COV2-2677_400
# 2  COV2-2082_400
# 3  COV2-2094_400
# 4  COV2-2165_400
# 5  COV2-2832_400
# 6  COV2-2479_400
# 7  COV2-2050_400
# 8  COV2-2096_400
# 9  COV2-2499_400

# %% [markdown]
# Now get all the escape-score samples of interest:

# %%
if not set(samples_to_subset).issubset(escape_score_samples['name']):
    raise ValueError(f"Not all samples to subset are in the escape score samples.")
    
samples_subset = (
    escape_score_samples
    .query('name in @samples_to_subset')
    .reset_index(drop=True)
    )

print(f"Here are the samples for which we are subsetting barcode runs:")
display(samples_subset)
# Out:
# Here are the samples for which we are subsetting barcode runs:
#              name library   antibody  concentration concentration_units  \
# 0   COV2-2050_400    lib1  COV2-2050            400           ng_per_mL
# 1   COV2-2050_400    lib2  COV2-2050            400           ng_per_mL
# 2   COV2-2082_400    lib1  COV2-2082            400           ng_per_mL
# 3   COV2-2082_400    lib2  COV2-2082            400           ng_per_mL
# 4   COV2-2094_400    lib1  COV2-2094            400           ng_per_mL
# 5   COV2-2094_400    lib2  COV2-2094            400           ng_per_mL
# 6   COV2-2096_400    lib1  COV2-2096            400           ng_per_mL
# 7   COV2-2096_400    lib2  COV2-2096            400           ng_per_mL
# 8   COV2-2165_400    lib1  COV2-2165            400           ng_per_mL
# 9   COV2-2165_400    lib2  COV2-2165            400           ng_per_mL
# 10  COV2-2479_400    lib1  COV2-2479            400           ng_per_mL
# 11  COV2-2479_400    lib2  COV2-2479            400           ng_per_mL
# 12  COV2-2499_400    lib1  COV2-2499            400           ng_per_mL
# 13  COV2-2499_400    lib2  COV2-2499            400           ng_per_mL
# 14  COV2-2677_400    lib1  COV2-2677            400           ng_per_mL
# 15  COV2-2677_400    lib2  COV2-2677            400           ng_per_mL
# 16  COV2-2832_400    lib1  COV2-2832            400           ng_per_mL
# 17  COV2-2832_400    lib2  COV2-2832            400           ng_per_mL
# 18     CR3022_400    lib1     CR3022            400           ng_per_mL
# 19     CR3022_400    lib2     CR3022            400           ng_per_mL
#
#       date                   pre_sample                   post_sample  \
# 0   200720  expt_13-16-none-0-reference  expt_13-COV2-2050-400-escape
# 1   200720  expt_13-16-none-0-reference  expt_13-COV2-2050-400-escape
# 2   200616   expt_7-11-none-0-reference  expt_11-COV2-2082-400-escape
# 3   200616   expt_7-11-none-0-reference  expt_11-COV2-2082-400-escape
# 4   200720  expt_13-16-none-0-reference  expt_14-COV2-2094-400-escape
# 5   200720  expt_13-16-none-0-reference  expt_14-COV2-2094-400-escape
# 6   200810  expt_22-23-none-0-reference  expt_23-COV2-2096-400-escape
# 7   200810  expt_22-23-none-0-reference  expt_23-COV2-2096-400-escape
# 8   200616   expt_7-11-none-0-reference   expt_9-COV2-2165-400-escape
# 9   200616   expt_7-11-none-0-reference   expt_9-COV2-2165-400-escape
# 10  200615    expt_3-6-none-0-reference   expt_5-COV2-2479-400-escape
# 11  200615    expt_3-6-none-0-reference   expt_5-COV2-2479-400-escape
# 12  200720  expt_13-16-none-0-reference  expt_15-COV2-2499-400-escape
# 13  200720  expt_13-16-none-0-reference  expt_15-COV2-2499-400-escape
# 14  200720  expt_13-16-none-0-reference  expt_16-COV2-2677-400-escape
# 15  200720  expt_13-16-none-0-reference  expt_16-COV2-2677-400-escape
# 16  200616   expt_7-11-none-0-reference  expt_10-COV2-2832-400-escape
# 17  200616   expt_7-11-none-0-reference  expt_10-COV2-2832-400-escape
# 18  200615    expt_3-6-none-0-reference      expt_3-CR3022-400-escape
# 19  200615    expt_3-6-none-0-reference      expt_3-CR3022-400-escape
#
#     frac_escape  pre_cells_sorted  post_cells_sorted
# 0         0.078         1253185.0        160000000.0
# 1         0.104         1588138.0        160000000.0
# 2         0.057          522474.0        160000000.0
# 3         0.086          512138.0        160000000.0
# 4         0.069          853420.0        160000000.0
# 5         0.071          954885.0        160000000.0
# 6         0.155         1018697.0        160000000.0
# 7         0.110          927621.0        160000000.0
# 8         0.071          911426.0        160000000.0
# 9         0.029          393068.0        160000000.0
# 10        0.050          684856.0        160000000.0
# 11        0.044          582089.0        160000000.0
# 12        0.177         2593041.0        160000000.0
# 13        0.185         2655138.0        160000000.0
# 14        0.086         1243786.0        160000000.0
# 15        0.088         1457488.0        160000000.0
# 16        0.116         1525920.0        160000000.0
# 17        0.076          975400.0        160000000.0
# 18        0.148         1790556.0        160000000.0
# 19        0.091         1175925.0        160000000.0

# %% [markdown]
# Now unfold the samples of interest into the actual relevant barcode runs (this requires getting both the pre- and post-selection run for each sample):

# %%
barcode_runs_subset = (
    samples_subset
    .melt(id_vars=['name', 'library'],
          value_vars=['pre_sample', 'post_sample'],
          value_name='sample',
          var_name='sample_type')
    [['library', 'sample']]
    .drop_duplicates()
    .reset_index(drop=True)
    .merge(barcode_runs,
           how='left',
           on=['library', 'sample'],
           validate='one_to_one',
           )
    )

assert barcode_runs_subset['R1'].notnull().all(), 'some barcode runs missing R1'

barcode_runs_subset_file = 'barcode_runs_subset.csv'
print(f"Here are the subsetted barcode runs. Writing to {barcode_runs_subset_file}")
barcode_runs_subset.to_csv(barcode_runs_subset_file, index=False)
display(barcode_runs_subset)
# Out:
# Here are the subsetted barcode runs. Writing to barcode_runs_subset.csv
#    library                        sample    date  experiment   antibody  \
# 0     lib1   expt_13-16-none-0-reference  200720  expt_13-16       none
# 1     lib2   expt_13-16-none-0-reference  200720  expt_13-16       none
# 2     lib1    expt_7-11-none-0-reference  200616   expt_7-11       none
# 3     lib2    expt_7-11-none-0-reference  200616   expt_7-11       none
# 4     lib1   expt_22-23-none-0-reference  200810  expt_22-23       none
# 5     lib2   expt_22-23-none-0-reference  200810  expt_22-23       none
# 6     lib1     expt_3-6-none-0-reference  200615    expt_3-6       none
# 7     lib2     expt_3-6-none-0-reference  200615    expt_3-6       none
# 8     lib1  expt_13-COV2-2050-400-escape  200720     expt_13  COV2-2050
# 9     lib2  expt_13-COV2-2050-400-escape  200720     expt_13  COV2-2050
# 10    lib1  expt_11-COV2-2082-400-escape  200616     expt_11  COV2-2082
# 11    lib2  expt_11-COV2-2082-400-escape  200616     expt_11  COV2-2082
# 12    lib1  expt_14-COV2-2094-400-escape  200720     expt_14  COV2-2094
# 13    lib2  expt_14-COV2-2094-400-escape  200720     expt_14  COV2-2094
# 14    lib1  expt_23-COV2-2096-400-escape  200810     expt_23  COV2-2096
# 15    lib2  expt_23-COV2-2096-400-escape  200810     expt_23  COV2-2096
# 16    lib1   expt_9-COV2-2165-400-escape  200616      expt_9  COV2-2165
# 17    lib2   expt_9-COV2-2165-400-escape  200616      expt_9  COV2-2165
# 18    lib1   expt_5-COV2-2479-400-escape  200615      expt_5  COV2-2479
# 19    lib2   expt_5-COV2-2479-400-escape  200615      expt_5  COV2-2479
# 20    lib1  expt_15-COV2-2499-400-escape  200720     expt_15  COV2-2499
# 21    lib2  expt_15-COV2-2499-400-escape  200720     expt_15  COV2-2499
# 22    lib1  expt_16-COV2-2677-400-escape  200720     expt_16  COV2-2677
# 23    lib2  expt_16-COV2-2677-400-escape  200720     expt_16  COV2-2677
# 24    lib1  expt_10-COV2-2832-400-escape  200616     expt_10  COV2-2832
# 25    lib2  expt_10-COV2-2832-400-escape  200616     expt_10  COV2-2832
# 26    lib1      expt_3-CR3022-400-escape  200615      expt_3     CR3022
# 27    lib2      expt_3-CR3022-400-escape  200615      expt_3     CR3022
#
#     concentration concentration_units   group  selection  frac_escape  \
# 0               0           ng_per_mL    none  reference          NaN
# 1               0           ng_per_mL    none  reference          NaN
# 2               0           ng_per_mL    none  reference          NaN
# 3               0           ng_per_mL    none  reference          NaN
# 4               0           ng_per_mL    none  reference          NaN
# 5               0           ng_per_mL    none  reference          NaN
# 6               0           ng_per_mL    none  reference          NaN
# 7               0           ng_per_mL    none  reference          NaN
# 8             400           ng_per_mL   Crowe     escape        0.078
# 9             400           ng_per_mL   Crowe     escape        0.104
# 10            400           ng_per_mL   Crowe     escape        0.057
# 11            400           ng_per_mL   Crowe     escape        0.086
# 12            400           ng_per_mL   Crowe     escape        0.069
# 13            400           ng_per_mL   Crowe     escape        0.071
# 14            400           ng_per_mL   Crowe     escape        0.155
# 15            400           ng_per_mL   Crowe     escape        0.110
# 16            400           ng_per_mL   Crowe     escape        0.071
# 17            400           ng_per_mL   Crowe     escape        0.029
# 18            400           ng_per_mL   Crowe     escape        0.050
# 19            400           ng_per_mL   Crowe     escape        0.044
# 20            400           ng_per_mL   Crowe     escape        0.177
# 21            400           ng_per_mL   Crowe     escape        0.185
# 22            400           ng_per_mL   Crowe     escape        0.086
# 23            400           ng_per_mL   Crowe     escape        0.088
# 24            400           ng_per_mL   Crowe     escape        0.116
# 25            400           ng_per_mL   Crowe     escape        0.076
# 26            400           ng_per_mL  CR3022     escape        0.148
# 27            400           ng_per_mL  CR3022     escape        0.091
#
#     cells_sorted                                                 R1
# 0    160000000.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 1    160000000.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 2    160000000.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 3    160000000.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 4    160000000.0  /shared/ngs/illumina/agreaney/200812_D00300_10...
# 5    160000000.0  /shared/ngs/illumina/agreaney/200812_D00300_10...
# 6    160000000.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 7    160000000.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 8      1253185.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 9      1588138.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 10      522474.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 11      512138.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 12      853420.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 13      954885.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 14     1018697.0  /shared/ngs/illumina/agreaney/200812_D00300_10...
# 15      927621.0  /shared/ngs/illumina/agreaney/200812_D00300_10...
# 16      911426.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 17      393068.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 18      684856.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 19      582089.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 20     2593041.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 21     2655138.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 22     1243786.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 23     1457488.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 24     1525920.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 25      975400.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 26     1790556.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# 27     1175925.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
